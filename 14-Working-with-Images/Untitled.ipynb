# %%
from PIL import Image

# %%
mac = Image.open("example.jpg")

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.format
# Out:
# 'JPEG'

# %%
mac.crop((885,850,1140,1140))
# Out:
# <PIL.Image.Image image mode=RGB size=255x290 at 0x7FBC14B46CA0>

# %%
pencils_img = Image.open("pencils.jpg")
pencils_img.size
# Out:
# (1950, 1300)

# %%
pencil_cropped = pencils_img.crop((0, 0, 600, 130))

# %%
pencil_cropped.paste()
